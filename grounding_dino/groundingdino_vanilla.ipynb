# %% [markdown]
# # Annotation from prompt with Grounding Dino
#
# #### Course:Deep Neural Engineering (IM1102)
# #### Group: Ellen Cordemans, Ilse Harmers & Sem Pepels
#
# The code in this notebook is partially based on the documentation on Hugging Face
# https://github.com/huggingface/transformers/blob/main/docs/source/en/model_doc/grounding-dino.md
#
# A font file is downloaded from https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmEU9vAw.ttf
#
# ---

# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForZeroShotObjectDetection
import matplotlib.pyplot as plt
from torchvision import io, utils
from torchvision import tv_tensors
from torchvision.transforms import v2
from torchvision.transforms.v2 import functional as F
from pathlib import Path
from roboflow import Roboflow

# %% [markdown]
# directory structure
#
# ```
# + Y:/ai/projects/IM1102
#   + run1
#   + ds/grounding_dino_vanilla
#         data.yaml
#         *.jpg
#         *.txt
#       + output
# ```

# %%
project_root = Path("Y:/ai/projects/IM1102")
yrun_dir =     Path("Y:/ai/projects/IM1102/run1")
dataset_dir =  Path("Y:/ai/projects/IM1102/ds/grounding_dino_vanilla")

# %%
#model_id = "IDEA-Research/grounding-dino-tiny"
model_id = "IDEA-Research/grounding-dino-base"
device = "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# %%
rf = Roboflow(api_key="your api key here")
project = rf.workspace().project("facadeparsingtest")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
def upload_annotated_image(imgfn, lblfn):
    project.single_upload(
        image_path          = imgfn,                       # opened as file
        annotation_path     = lblfn,
        annotation_labelmap = str(dataset_dir/"data.yaml") # opened as file only if this is a string
    )

# %%
def run_model(imgfn, lblfn, outimgfn):
    image = Image.open(imgfn)
    w, h = image.size
    textlabels = [["0", "door", "front yard", "window"]]
    class2name = {'0':'0', '1':'door', '2':'front yard', '3':'window'}
    name2class = {v: k for k, v in class2name.items()}
    inputs = processor(images=image, text=textlabels, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model(**inputs)
    results = processor.post_process_grounded_object_detection(
        outputs, inputs.input_ids, threshold=0.4, text_threshold=0.3, target_sizes=[image.size[::-1]])
    result = results[0]
    result["colors"] = []
    result["lines"]  = []
    for box, labels in zip(result["boxes"], result["text_labels"]):
        if   labels == 'door':        color='green'
        elif labels == 'window':      color='red'
        elif labels == 'front yard':  color='blue'
        else:                         color='black'
        result["colors"].append(color)
        [x1, y1, x2, y2] = box
        ixywh = [ 
            name2class[labels], 
            "{:.6f}".format( (x1 + ((x2-x1)/2))/w ), 
            "{:.6f}".format( (y1 + ((y2-y1)/2))/h ), 
            "{:.6f}".format( (x2-x1)/w ), 
            "{:.6f}".format( (y2-y1)/h ) 
        ]
        result["lines"].append(' '.join(ixywh))
    lblfn.write_text("\n".join(sorted(result["lines"])))
    viz = utils.draw_bounding_boxes(F.pil_to_tensor(image), boxes=result['boxes'], labels=result['text_labels'], 
                                    font='KFOlCnqEu92Fr1MmEU9vAw.ttf', font_size=25, colors=result['colors'], width=4)
    imgo = F.to_pil_image(viz)
    imgo.save(outimgfn)
    #print(result)
    return imgfn, lblfn

# %%
flist = sorted(Path(dataset_dir).glob('*.jpg'))
for imgfn in flist:
    print(imgfn)
    lblfn    = dataset_dir/ (imgfn.stem+'.txt')
    outimgfn = dataset_dir/ ('output/'+imgfn.stem+'.png')
    imgfn, lblfn = run_model(imgfn, lblfn, outimgfn)
    upload_annotated_image(imgfn, lblfn)
# Out:
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\40294018_337_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\42087266_279_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\42132455_415_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\42340258_879_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\42340258_880_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\42785832_417_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43407668_062_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43429591_815_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43491751_938_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43545600_929_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43610079_438_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43625880_858_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43626026_723_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43660062_578_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43672059_643_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43689253_736_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43699435_271_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43704927_615_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43721795_169_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43741299_386_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43761332_083_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43770741_583_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43781666_287_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43786376_593_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43789424_742_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43808971_546_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43809318_159_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43829840_964_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43855272_140_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43885064_746_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\43895244_397_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88355902_500_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88499481_443_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88499481_627_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88520972_939_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88539390_009_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88548680_827_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88559254_303_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88607433_871_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88641146_190_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88667251_539_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88667563_786_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88672106_449_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88675297_048_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88692047_304_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88695460_221_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88707213_642_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88723972_326_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88727385_832_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88750612_243_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88769893_527_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88780187_202_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88796136_427_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88889404_639_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\88900536_651_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89007267_862_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89007865_100_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89021042_626_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89023492_383_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89031212_809_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89039052_287_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89039412_964_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89039818_343_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89043419_563_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89043807_031_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89050236_645_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89051640_203_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89054009_541_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89055574_179_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89057338_581_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89064712_440_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89064875_972_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89083443_591_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89086161_307_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89087150_140_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89091793_490_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89098033_244_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89100008_335_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89100449_250_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89103920_999_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89105160_275_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89106635_011_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89108158_742_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89108771_445_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89118744_139_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89123668_451_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89126236_098_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89126236_108_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89127377_911_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89130061_053_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89132467_084_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89134752_808_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89137357_943_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89139928_804_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89140721_369_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89140820_806_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89143432_857_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89146736_979_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89148725_444_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89151163_593_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89166101_816_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89166634_562_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89175055_410_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89179703_133_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89181736_910_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89184013_010_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89189268_895_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89194429_041_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89196147_171_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89198423_813_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89211220_652_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89215906_530_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89217041_456_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89220782_214_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89223248_032_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89226000_168_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89227440_983_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89230416_931_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89231033_515_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89234587_297_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89234858_963_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89243689_640_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89243689_644_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89248431_490_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89248482_949_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89248772_439_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89252359_744_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89254717_217_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89255788_134_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89258320_321_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89258925_380_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89262343_425_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89265822_289_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89266579_150_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89268130_132_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89268515_149_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89274937_818_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89275857_695_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89276356_798_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89276361_069_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89277065_336_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89279585_905_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89280427_307_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89281225_015_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89281226_143_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89281226_169_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89282318_509_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89282405_082_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89282978_337_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89285164_765_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89286274_908_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89288528_452_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89291271_050_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89299438_270_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89807381_617_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89807523_025_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89821946_641_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89857488_092_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89860557_916_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89864187_172_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89877606_848_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89884101_883_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89884101_884_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89884284_381_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89890183_897_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89892304_306_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89897769_572_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89897846_729_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89915316_485_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89919895_317_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89951512_863_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89952840_151_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89954887_192_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89954893_745_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89962257_074_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89965480_037_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89966230_339_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89969335_822_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89975015_963_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89979769_247_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89995892_813_1440x960.jpg
# Y:\ai\projects\IM1102\ds\grounding_dino_vanilla\89997278_214_1440x960.jpg
